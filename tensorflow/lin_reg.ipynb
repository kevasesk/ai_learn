# %%
import math, random, os
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib as mpl

import tensorflow as tf
# Out:
# 2025-05-05 21:46:29.005825: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-05 21:46:29.007049: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-05-05 21:46:29.045639: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-05-05 21:46:29.252068: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-05-05 21:46:29.930896: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
X = 2 * np.random.rand(100,1)
y = 4 + 3 * X + np.random.randn(100,1)

X = np.c_[np.ones((100,1)), X]  # add x0 = 1 to each instance

XT = tf.transpose(X)
theta = tf.linalg.inv(XT @ X) @ XT @ y


#plt.plot(X, y, "b.")
#plt.plot(X, X @ theta, "r-")

x_new = np.array([[0], [2]])
x_new_b = np.c_[np.ones((2,1)), x_new]  # add x0 = 1 to each instance

plt.plot(X[:, 1], y, "b.")
plt.plot(x_new_b, x_new_b @ theta, "r-")

plt.axis([0, 2, 0, 15])
plt.show()
